# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_boston
from sklearn.metrics import r2_score

import pandas as pd
import numpy as np
import torch
import seaborn as sns

import matplotlib.pyplot as plt

# %%
boston = load_boston()

# %%
data_frame = pd.DataFrame(boston.data)
data_frame.columns = boston.feature_names
data_frame['MEDV'] = boston.target

# %%
# check for dirty data

percent_of_empty_data = data_frame.replace(0, np.nan, inplace=True)
print("Amount of data cells with '0' replaced by NaN: " + str(percent_of_empty_data))

percent_of_nan_data = data_frame.isnull().sum() / len(data_frame)
print("Percent of NaN data cells: \n" + str(percent_of_nan_data))
# Out:
# Amount of data cells with '0' replaced by NaN: None
# Percent of NaN data cells:
# CRIM       0.000000
# ZN         0.735178
# INDUS      0.000000
# CHAS       0.930830
# NOX        0.000000
# RM         0.000000
# AGE        0.000000
# DIS        0.000000
# RAD        0.000000
# TAX        0.000000
# PTRATIO    0.000000
# B          0.000000
# LSTAT      0.000000
# MEDV       0.000000
# dtype: float64

# %%
# clean dirty data
data_frame = data_frame.drop("ZN", axis=1)
data_frame = data_frame.drop("CHAS", axis=1)

# %%
# check for dataset normal distribution constrain

plt.hist(data_frame['MEDV'])
# Out:
# (array([ 21.,  55.,  82., 154.,  84.,  41.,  30.,   8.,  10.,  21.]),
#  array([ 5. ,  9.5, 14. , 18.5, 23. , 27.5, 32. , 36.5, 41. , 45.5, 50. ]),
#  <a list of 10 Patch objects>)

# %%
# look for correlated data, avoid multi correlated data (features that depends on each other) within regression feature

corr = data_frame.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

sns.set(rc={'figure.figsize': (20, 20)})
sns.heatmap(corr, mask=mask, square=True, cmap='YlGnBu', annot=True)

# %%
# our choice
# medv:rm (+) medv:lstat(-) 

# drop columns
# [tax:rad (+), tax:indus(+) dis:indus(-) dis:age(-) dis:noz(-) age:nox(+) nox:indus(+)]

# %%
# just to visually confirm selected columns  
for i in range(0, len(data_frame.columns), 5):
    sns.pairplot(data=data_frame,
                x_vars=data_frame.columns[i:i+5],
                y_vars=['MEDV'])

# %%
# to see the difference between raw and normalized input data try raw dataset first
data_frame['LOGLSTAT'] = data_frame['LSTAT'].apply(np.log)
data_frame['LOGCRIM'] = data_frame['CRIM'].apply(np.log)
data_frame['LOGDIS'] = data_frame['DIS'].apply(np.log)
data_frame['LOGTAX'] = data_frame['TAX'].apply(np.log)

# %%
X = data_frame[["LOGCRIM", "LOGDIS", "LOGTAX", "LOGLSTAT", "RM"]].to_numpy()

X = (X - X.mean()) / X.std()
X = np.c_[np.ones(X.shape[0]), X] 

y = data_frame["MEDV"].to_numpy()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)

# %%
from sklearn.preprocessing import RobustScaler

scaler= RobustScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
# test with sklearn regressor
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
test_model = regressor.fit(X_train, y_train)
y_predict = test_model.predict(X_train)

r2 = r2_score(y_train, y_predict)

print(f'R2 score={r2}, on validation dataset={regressor.score(X_test, y_test)}')
# Out:
# R2 score=0.7489148743258148, on validation dataset=0.6094003108243633

# %%
# verify r2 score on the model
def verify_score(model, X_test, y_test):
    
    model.eval()

    if torch.is_tensor(X_test) != True:
        X_test = torch.from_numpy(X_test).clone()
        y_test = torch.from_numpy(y_test).clone().reshape(-1,1)

    y_pred = model(X_test)
    # y_pred = y_pred.reshape(-1,-1)

    y_train_np = np.around(y_test, decimals=1).numpy()
    predicts_np = np.around(y_pred.clone().detach(), decimals=1).numpy()

    r2 = r2_score(y_train_np, predicts_np)

    print(f'r2 score = {r2}')
    
    return r2

# %%
# convert to the required shape 
X_train = torch.from_numpy(X_train).clone()
y_train = torch.from_numpy(y_train).clone().reshape(-1,1)

# %%
# architect the model
input_w_num = X_train.shape[1]
output_w_num = input_w_num * 3
model = torch.nn.Sequential(
    torch.nn.Linear(input_w_num, output_w_num, bias=True), torch.nn.ELU(),
    torch.nn.Linear(output_w_num, output_w_num, bias=True), torch.nn.ELU(),
    torch.nn.Dropout(p=0.2),
    torch.nn.Linear(output_w_num, input_w_num, bias = True), torch.nn.Sigmoid(),
    torch.nn.Linear(input_w_num, 1)
)

model.load_state_dict(torch.load('model_state.txt'))
model.eval()
# Out:
# Sequential(
#   (0): Linear(in_features=6, out_features=18, bias=True)
#   (1): ELU(alpha=1.0)
#   (2): Linear(in_features=18, out_features=18, bias=True)
#   (3): ELU(alpha=1.0)
#   (4): Dropout(p=0.2, inplace=False)
#   (5): Linear(in_features=18, out_features=6, bias=True)
#   (6): Sigmoid()
#   (7): Linear(in_features=6, out_features=1, bias=True)
# )

# %%
model.double()
r2 = verify_score(model, X_test, y_test)
is_skip_training = r2 > 0.75

print("Skip training: " % is_skip_training)

intentionally stop chain execution
# Out:
# r2 score = 0.7449658505152696
# Skip training:

# %%
loss = torch.nn.MSELoss()
optimizer = torch.optim.RMSprop(model.parameters(), lr=1e-4)

# %%
# %%time
num_epoch = 16000
def train_model(model, loss, optimizer, x_train, y_train, num_epoch):
    train_accuracy_history = []
    train_avg_loss_history = []
    model.train()
    for n in range(num_epoch):
        correct_samples = 0
        total_samples = 0
        loss_accum = 0
        y_predicts = model(x_train)
        y_predicts = y_predicts.reshape(-1,1)
        loss_value = loss(y_train, y_predicts)
        loss_value.backward()
        optimizer.step()
        optimizer.zero_grad()
        
        y_train_np = np.around(y_train, decimals=1).numpy()
        predicts_np = np.around(y_predicts.clone().detach(), decimals=1).numpy()
        
        correct_samples += np.sum(y_train_np == predicts_np)
        total_samples += y_train.shape[0]

        train_accuracy = float(correct_samples) / total_samples

        train_accuracy_history.append(train_accuracy)
        train_avg_loss_history.append(loss_value)
        
        r2 = r2_score(y_train_np, predicts_np)
        
        if n > 0 and (n % 100 == 0):
            print(f"Epoch={n}, train_avg_loss={loss_value}, train_accuracy={train_accuracy}. r2_score={r2}")

    return train_accuracy_history, train_avg_loss_history
# Out:
# Wall time: 0 ns

# %%
# %%time
# train the model
model = model.double()
X_train = X_train.double()
y_train = y_train.double()
(train_accuracy_history, train_avg_loss_history) = train_model(model, loss, optimizer, X_train, y_train, num_epoch)
# Out:
# Epoch=100, train_avg_loss=9.646637064338872, train_accuracy=0.01694915254237288. r2_score=0.8758423503805624
# Epoch=200, train_avg_loss=9.967626536011664, train_accuracy=0.014124293785310734. r2_score=0.8717568082990962
# Epoch=300, train_avg_loss=9.392047375938251, train_accuracy=0.011299435028248588. r2_score=0.8791145652718317
# Epoch=400, train_avg_loss=10.034957282647634, train_accuracy=0.025423728813559324. r2_score=0.8707635092898798
# Epoch=500, train_avg_loss=9.939890510501522, train_accuracy=0.00847457627118644. r2_score=0.8720407638357719
# Epoch=600, train_avg_loss=9.673499020181996, train_accuracy=0.014124293785310734. r2_score=0.875542760928295
# Epoch=700, train_avg_loss=9.904726629458919, train_accuracy=0.01977401129943503. r2_score=0.8723418076057687
# Epoch=800, train_avg_loss=9.402967492203658, train_accuracy=0.014124293785310734. r2_score=0.8789691334988865
# Epoch=900, train_avg_loss=9.78111923694965, train_accuracy=0.01694915254237288. r2_score=0.8740637197974411
# Epoch=1000, train_avg_loss=9.632667114183587, train_accuracy=0.01694915254237288. r2_score=0.8761081269456199
# Epoch=1100, train_avg_loss=9.861224498138364, train_accuracy=0.01694915254237288. r2_score=0.8729140816323084
# Epoch=1200, train_avg_loss=9.720894850354592, train_accuracy=0.01694915254237288. r2_score=0.8748745019316113
# Epoch=1300, train_avg_loss=9.854732681618566, train_accuracy=0.025423728813559324. r2_score=0.8731420459364003
# Epoch=1400, train_avg_loss=10.050336551224204, train_accuracy=0.022598870056497175. r2_score=0.870746784635991
# Epoch=1500, train_avg_loss=9.334280122866913, train_accuracy=0.00847457627118644. r2_score=0.8798817178741183
# Epoch=1600, train_avg_loss=9.708140717709021, train_accuracy=0.031073446327683617. r2_score=0.8750170250690976
# Epoch=1700, train_avg_loss=9.366562247669052, train_accuracy=0.01694915254237288. r2_score=0.8794105189297755
# Epoch=1800, train_avg_loss=9.489926075580557, train_accuracy=0.01977401129943503. r2_score=0.8779354771726777
# Epoch=1900, train_avg_loss=9.57724021626343, train_accuracy=0.00847457627118644. r2_score=0.8765735086190448
# Epoch=2000, train_avg_loss=9.285974939865376, train_accuracy=0.01694915254237288. r2_score=0.8803856389673738
# Epoch=2100, train_avg_loss=9.777541086641603, train_accuracy=0.014124293785310734. r2_score=0.8740070014059924
# Epoch=2200, train_avg_loss=9.200043452828861, train_accuracy=0.011299435028248588. r2_score=0.8814741957878695
# Epoch=2300, train_avg_loss=9.101330201176529, train_accuracy=0.011299435028248588. r2_score=0.8829397844797258
# Epoch=2400, train_avg_loss=9.718994337557023, train_accuracy=0.014124293785310734. r2_score=0.8748410526238338
# Epoch=2500, train_avg_loss=9.128278513807713, train_accuracy=0.01694915254237288. r2_score=0.8825347569920731
# Epoch=2600, train_avg_loss=9.51600051025759, train_accuracy=0.00847457627118644. r2_score=0.8776417049913282
# Epoch=2700, train_avg_loss=9.490755981451436, train_accuracy=0.01694915254237288. r2_score=0.8777660491571964
# Epoch=2800, train_avg_loss=9.239236523275926, train_accuracy=0.025423728813559324. r2_score=0.8812207809235122
# Epoch=2900, train_avg_loss=9.334079594647607, train_accuracy=0.031073446327683617. r2_score=0.8799060776960866
# Epoch=3000, train_avg_loss=9.493067527677278, train_accuracy=0.022598870056497175. r2_score=0.8778358564082102
# Epoch=3100, train_avg_loss=9.102908026787109, train_accuracy=0.00847457627118644. r2_score=0.8828743401819004
# Epoch=3200, train_avg_loss=9.14270808850327, train_accuracy=0.01694915254237288. r2_score=0.8824198658914463
# Epoch=3300, train_avg_loss=8.994584888027733, train_accuracy=0.03672316384180791. r2_score=0.8843108425191677
# Epoch=3400, train_avg_loss=9.28723339623585, train_accuracy=0.01977401129943503. r2_score=0.8803463723886785
# Epoch=3500, train_avg_loss=9.138974592779299, train_accuracy=0.01977401129943503. r2_score=0.8825249403473994
# Epoch=3600, train_avg_loss=9.068856418653034, train_accuracy=0.01694915254237288. r2_score=0.8832244671752663
# Epoch=3700, train_avg_loss=9.486138404141101, train_accuracy=0.01977401129943503. r2_score=0.8779620184712402
# Epoch=3800, train_avg_loss=9.13766034746687, train_accuracy=0.01977401129943503. r2_score=0.8823464228461089
# Epoch=3900, train_avg_loss=9.436729481158746, train_accuracy=0.014124293785310734. r2_score=0.8785539257871277
# Epoch=4000, train_avg_loss=8.765067522143045, train_accuracy=0.014124293785310734. r2_score=0.8871056776157442
# Epoch=4100, train_avg_loss=9.731150446032565, train_accuracy=0.011299435028248588. r2_score=0.8748399618855367
# Epoch=4200, train_avg_loss=8.840392227968826, train_accuracy=0.011299435028248588. r2_score=0.8864992271225622
# Epoch=4300, train_avg_loss=9.516953896266278, train_accuracy=0.00847457627118644. r2_score=0.8773930166595917
# Epoch=4400, train_avg_loss=8.957559230105069, train_accuracy=0.014124293785310734. r2_score=0.8845231729076679
# Epoch=4500, train_avg_loss=8.789024306660309, train_accuracy=0.00847457627118644. r2_score=0.8868220856585008
# Epoch=4600, train_avg_loss=9.117151453024942, train_accuracy=0.01977401129943503. r2_score=0.8826634641111297
# Epoch=4700, train_avg_loss=8.90942658916095, train_accuracy=0.031073446327683617. r2_score=0.8854161239935521
# Epoch=4800, train_avg_loss=8.791631315893618, train_accuracy=0.011299435028248588. r2_score=0.886622116970701
# Epoch=4900, train_avg_loss=8.992648222884327, train_accuracy=0.03389830508474576. r2_score=0.8843653794340222
# Epoch=5000, train_avg_loss=8.796078593791584, train_accuracy=0.014124293785310734. r2_score=0.8868409917889837
# Epoch=5100, train_avg_loss=9.057001965413306, train_accuracy=0.005649717514124294. r2_score=0.8835146035622921
# Epoch=5200, train_avg_loss=9.058504247117705, train_accuracy=0.011299435028248588. r2_score=0.8831942900823802
# Epoch=5300, train_avg_loss=8.964977700906097, train_accuracy=0.014124293785310734. r2_score=0.8847333218195738
# Epoch=5400, train_avg_loss=8.819582373670709, train_accuracy=0.01977401129943503. r2_score=0.8862269061277221
# Epoch=5500, train_avg_loss=9.24497478772885, train_accuracy=0.005649717514124294. r2_score=0.8811258866916654
# Epoch=5600, train_avg_loss=8.861966903742651, train_accuracy=0.00847457627118644. r2_score=0.8860262102810577
# Epoch=5700, train_avg_loss=9.020414429675041, train_accuracy=0.01977401129943503. r2_score=0.8837174808855508
# Epoch=5800, train_avg_loss=8.966556559589616, train_accuracy=0.01694915254237288. r2_score=0.88461733998065
# Epoch=5900, train_avg_loss=8.888381326264378, train_accuracy=0.01977401129943503. r2_score=0.8855819162147097
# Epoch=6000, train_avg_loss=8.681998354718289, train_accuracy=0.025423728813559324. r2_score=0.8882422269213118
# Epoch=6100, train_avg_loss=9.192677791021, train_accuracy=0.014124293785310734. r2_score=0.8818334122670444
# Epoch=6200, train_avg_loss=8.432299195766113, train_accuracy=0.01694915254237288. r2_score=0.8916169712125077
# Epoch=6300, train_avg_loss=9.17490240998313, train_accuracy=0.011299435028248588. r2_score=0.881818141930885
# Epoch=6400, train_avg_loss=10.163731621733243, train_accuracy=0.01977401129943503. r2_score=0.8692913761682408
# Epoch=6500, train_avg_loss=8.940359569796367, train_accuracy=0.031073446327683617. r2_score=0.8849841916279044
# Epoch=6600, train_avg_loss=8.533620527971637, train_accuracy=0.04519774011299435. r2_score=0.8901437473525717
# Epoch=6700, train_avg_loss=8.458846897664696, train_accuracy=0.03389830508474576. r2_score=0.8908349118534943
# Epoch=6800, train_avg_loss=8.72763148473271, train_accuracy=0.00847457627118644. r2_score=0.8875267025984208
# Epoch=6900, train_avg_loss=9.009019815633119, train_accuracy=0.00847457627118644. r2_score=0.8837243888947658
# Epoch=7000, train_avg_loss=8.627052805817627, train_accuracy=0.025423728813559324. r2_score=0.8888941248435391
# Epoch=7100, train_avg_loss=8.431789849019491, train_accuracy=0.005649717514124294. r2_score=0.8914319092814348
# Epoch=7200, train_avg_loss=9.064308324534975, train_accuracy=0.01694915254237288. r2_score=0.8833691717893468
# Epoch=7300, train_avg_loss=8.787516918851027, train_accuracy=0.022598870056497175. r2_score=0.886849354115928
# Epoch=7400, train_avg_loss=8.433484746292315, train_accuracy=0.022598870056497175. r2_score=0.8914973535792602
# Epoch=7500, train_avg_loss=8.2777881382511, train_accuracy=0.022598870056497175. r2_score=0.8935297626061709
# Epoch=7600, train_avg_loss=8.540261867413937, train_accuracy=0.01694915254237288. r2_score=0.8899725014399287
# Epoch=7700, train_avg_loss=8.793591584663039, train_accuracy=0.00847457627118644. r2_score=0.8867759110705907
# Epoch=7800, train_avg_loss=9.162765246810674, train_accuracy=0.00847457627118644. r2_score=0.8817501525770332
# Epoch=7900, train_avg_loss=8.909053225942762, train_accuracy=0.014124293785310734. r2_score=0.8853983086013663
# Epoch=8000, train_avg_loss=8.254677934210616, train_accuracy=0.025423728813559324. r2_score=0.8937217325464587
# Epoch=8100, train_avg_loss=8.819394132252551, train_accuracy=0.01977401129943503. r2_score=0.8865144974587215
# Epoch=8200, train_avg_loss=8.199862529040209, train_accuracy=0.005649717514124294. r2_score=0.8945801435862684
# Epoch=8300, train_avg_loss=9.06881492196632, train_accuracy=0.014124293785310734. r2_score=0.8833364496404341
# Epoch=8400, train_avg_loss=8.806032877755053, train_accuracy=0.022598870056497175. r2_score=0.8864672321325142
# Epoch=8500, train_avg_loss=8.847430426813796, train_accuracy=0.031073446327683617. r2_score=0.8860658404391852
# Epoch=8600, train_avg_loss=8.375664237730357, train_accuracy=0.011299435028248588. r2_score=0.8922470543687933
# Epoch=8700, train_avg_loss=8.703698528454993, train_accuracy=0.025423728813559324. r2_score=0.8880960679895018
# Epoch=8800, train_avg_loss=8.748501835076413, train_accuracy=0.005649717514124294. r2_score=0.8873205530602709
# Epoch=8900, train_avg_loss=8.926989209816773, train_accuracy=0.011299435028248588. r2_score=0.8851252604476614
# Epoch=9000, train_avg_loss=8.274625232906981, train_accuracy=0.00847457627118644. r2_score=0.8935261268118473
# Epoch=9100, train_avg_loss=8.903501216658556, train_accuracy=0.025423728813559324. r2_score=0.8853910370127189
# Epoch=9200, train_avg_loss=9.355551249107345, train_accuracy=0.022598870056497175. r2_score=0.8797555558110882
# Epoch=9300, train_avg_loss=8.817853511940006, train_accuracy=0.01694915254237288. r2_score=0.8862236339128309
# Epoch=9400, train_avg_loss=8.277870689357346, train_accuracy=0.01977401129943503. r2_score=0.8933494272077187
# Epoch=9500, train_avg_loss=8.300032315177264, train_accuracy=0.01977401129943503. r2_score=0.8931407326135422
# Epoch=9600, train_avg_loss=8.375649352914998, train_accuracy=0.01977401129943503. r2_score=0.8922757771439499
# Epoch=9700, train_avg_loss=8.888016165677014, train_accuracy=0.02824858757062147. r2_score=0.8855960958125719
# Epoch=9800, train_avg_loss=8.649534176528583, train_accuracy=0.014124293785310734. r2_score=0.8885796286345449
# Epoch=9900, train_avg_loss=8.369097211633695, train_accuracy=0.022598870056497175. r2_score=0.8923379492268841
# Epoch=10000, train_avg_loss=8.91768491946508, train_accuracy=0.025423728813559324. r2_score=0.8852154281468875
# Epoch=10100, train_avg_loss=8.648978014305753, train_accuracy=0.00847457627118644. r2_score=0.8886116236245929
# Epoch=10200, train_avg_loss=8.833164329344914, train_accuracy=0.014124293785310734. r2_score=0.8863672477886144
# Epoch=10300, train_avg_loss=8.269614998959614, train_accuracy=0.01977401129943503. r2_score=0.8936871925003842
# Epoch=10400, train_avg_loss=8.42505642602834, train_accuracy=0.01694915254237288. r2_score=0.8916009737174837
# Epoch=10500, train_avg_loss=8.749356494391899, train_accuracy=0.01694915254237288. r2_score=0.887463803356622
# Epoch=10600, train_avg_loss=7.168158151095854, train_accuracy=0.022598870056497175. r2_score=0.9078071633356444
# Epoch=10700, train_avg_loss=8.51382278668298, train_accuracy=0.022598870056497175. r2_score=0.8902128274447207
# Epoch=10800, train_avg_loss=8.67580851964894, train_accuracy=0.002824858757062147. r2_score=0.8882618602106594
# Epoch=10900, train_avg_loss=8.616676805361603, train_accuracy=0.014124293785310734. r2_score=0.8889999264583569
# Epoch=11000, train_avg_loss=9.008527374932154, train_accuracy=0.022598870056497175. r2_score=0.8841225083732035
# Epoch=11100, train_avg_loss=8.589272181202814, train_accuracy=0.025423728813559324. r2_score=0.88950348397218
# Epoch=11200, train_avg_loss=8.714242140960849, train_accuracy=0.01977401129943503. r2_score=0.8876415936990476
# Epoch=11300, train_avg_loss=8.452760327448345, train_accuracy=0.00847457627118644. r2_score=0.8912421208177412
# Epoch=11400, train_avg_loss=8.256905746699006, train_accuracy=0.00847457627118644. r2_score=0.8936577425663628
# Epoch=11500, train_avg_loss=8.402984230319461, train_accuracy=0.005649717514124294. r2_score=0.8917954887137981
# Epoch=11600, train_avg_loss=8.51905429535699, train_accuracy=0.025423728813559324. r2_score=0.8903237191715915
# Epoch=11700, train_avg_loss=8.449492719395273, train_accuracy=0.01694915254237288. r2_score=0.8911995820241547
# Epoch=11800, train_avg_loss=8.77694302669037, train_accuracy=0.01694915254237288. r2_score=0.8870860443263966
# Epoch=11900, train_avg_loss=8.522627532435077, train_accuracy=0.03389830508474576. r2_score=0.8902808167985727
# Epoch=12000, train_avg_loss=8.381966195982695, train_accuracy=0.022598870056497175. r2_score=0.8921576138284318
# Epoch=12100, train_avg_loss=8.394520042714818, train_accuracy=0.005649717514124294. r2_score=0.8918627509087853
# Epoch=12200, train_avg_loss=8.39107282653518, train_accuracy=0.01977401129943503. r2_score=0.8920347239802932
# Epoch=12300, train_avg_loss=8.581812965338827, train_accuracy=0.01694915254237288. r2_score=0.8895478406629284
# Epoch=12400, train_avg_loss=8.456423079908452, train_accuracy=0.01977401129943503. r2_score=0.8912693892751684
# Epoch=12500, train_avg_loss=8.302260998306233, train_accuracy=0.01977401129943503. r2_score=0.893228718836174
# Epoch=12600, train_avg_loss=8.190135020924558, train_accuracy=0.01977401129943503. r2_score=0.8946059577259662
# Epoch=12700, train_avg_loss=8.806717303503925, train_accuracy=0.01694915254237288. r2_score=0.8865643078409553
# Epoch=12800, train_avg_loss=8.628380737296629, train_accuracy=0.011299435028248588. r2_score=0.888961023459094
# Epoch=12900, train_avg_loss=8.38729117859998, train_accuracy=0.00847457627118644. r2_score=0.8920830800447974
# Epoch=13000, train_avg_loss=8.31197746861943, train_accuracy=0.014124293785310734. r2_score=0.8932581687701956
# Epoch=13100, train_avg_loss=8.37552184492595, train_accuracy=0.01977401129943503. r2_score=0.8923335862736957
# Epoch=13200, train_avg_loss=8.1810018399131, train_accuracy=0.01694915254237288. r2_score=0.894867007758403
# Epoch=13300, train_avg_loss=8.191699512783194, train_accuracy=0.011299435028248588. r2_score=0.8945648732501091
# Epoch=13400, train_avg_loss=8.305524224480907, train_accuracy=0.014124293785310734. r2_score=0.8931080104646295
# Epoch=13500, train_avg_loss=8.074824097706559, train_accuracy=0.01977401129943503. r2_score=0.8960693649412284
# Epoch=13600, train_avg_loss=8.76954775378215, train_accuracy=0.02824858757062147. r2_score=0.8871958453149703
# Epoch=13700, train_avg_loss=8.40871248096694, train_accuracy=0.01977401129943503. r2_score=0.8917373160046199
# Epoch=13800, train_avg_loss=8.130667698056838, train_accuracy=0.01977401129943503. r2_score=0.895291304955971
# Epoch=13900, train_avg_loss=9.099755864123551, train_accuracy=0.031073446327683617. r2_score=0.8828143495755605
# Epoch=14000, train_avg_loss=8.573861613670259, train_accuracy=0.014124293785310734. r2_score=0.8895205722055011
# Epoch=14100, train_avg_loss=8.34149887683256, train_accuracy=0.014124293785310734. r2_score=0.8927549748358048
# Epoch=14200, train_avg_loss=8.255485664682707, train_accuracy=0.00847457627118644. r2_score=0.8937344578265914
# Epoch=14300, train_avg_loss=7.9006299268461095, train_accuracy=0.01694915254237288. r2_score=0.8983875474019766
# Epoch=14400, train_avg_loss=8.135993238031054, train_accuracy=0.01977401129943503. r2_score=0.8951204226227603
# Epoch=14500, train_avg_loss=8.447447315306853, train_accuracy=0.02824858757062147. r2_score=0.8913242897694553
# Epoch=14600, train_avg_loss=8.484810905037476, train_accuracy=0.00847457627118644. r2_score=0.8907632867053187
# Epoch=14700, train_avg_loss=8.224335443503168, train_accuracy=0.01694915254237288. r2_score=0.8941002187355489
# Epoch=14800, train_avg_loss=8.313156696762128, train_accuracy=0.01694915254237288. r2_score=0.8930938308667673
# Epoch=14900, train_avg_loss=8.203859086275544, train_accuracy=0.02824858757062147. r2_score=0.8943063682736988
# Epoch=15000, train_avg_loss=8.269947315200776, train_accuracy=0.025423728813559324. r2_score=0.8936217482025588
# Epoch=15100, train_avg_loss=7.901012182896525, train_accuracy=0.01977401129943503. r2_score=0.8982991975999124
# Epoch=15200, train_avg_loss=8.338391516219819, train_accuracy=0.01694915254237288. r2_score=0.8925640956338141
# Epoch=15300, train_avg_loss=8.638069062497609, train_accuracy=0.00847457627118644. r2_score=0.8886359834465611
# Epoch=15400, train_avg_loss=8.351381229173839, train_accuracy=0.002824858757062147. r2_score=0.8923590368339611
# Epoch=15500, train_avg_loss=8.408599121343757, train_accuracy=0.014124293785310734. r2_score=0.8920550844285055
# Epoch=15600, train_avg_loss=8.607632584840207, train_accuracy=0.022598870056497175. r2_score=0.8891853519688622
# Epoch=15700, train_avg_loss=8.626778407325734, train_accuracy=0.005649717514124294. r2_score=0.8889672043094441
# Epoch=15800, train_avg_loss=7.728822129530995, train_accuracy=0.01694915254237288. r2_score=0.9005682968372916
# Epoch=15900, train_avg_loss=8.0236145661301, train_accuracy=0.025423728813559324. r2_score=0.8969048704767992
# Wall time: 43.9 s

# %%
plt.plot(np.array(train_avg_loss_history), '+')
plt.xlabel('Epoch')
plt.ylabel('Loss value')
plt.show()

# %%
# you converge the model, but with overfitting
# you want to include others valuable feature, but it would not work with Linear regression, at least as single layer

# %%
r2 = verify_score(model, X_test, y_test)
# Out:
# r2 score = 0.7449658505152696

# %%
torch.save(model.state_dict(), 'model_state.txt')
